# %%
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import scipy
import PIL
import requests

# %%
# load data, removing spaces in column headers
columns = ["Customer_ID", "Age", "Gender", "Item_Purchased", "Item_Category", "Purchase_Amount_(USD)", "Location", "Color", "Season", "Review_Rating", "Subscription_Status", "Shipping_Type", "Discount_Applied", "Promo_Code_Used", "Previous_Purchases", "Payment Method", "Frequency of Purchases"]
df = pd.read_csv("../data/Customers3.csv", header = 0, names = columns)
df
# Out:
#       Customer_ID  Age  Gender Item_Purchased Item_Category  \
# 0               1   55    Male         Blouse      Clothing
# 1               2   19    Male        Sweater      Clothing
# 2               3   50    Male          Jeans      Clothing
# 3               4   21    Male        Sandals      Footwear
# 4               5   45    Male         Blouse      Clothing
# ...           ...  ...     ...            ...           ...
# 3895         3896   40  Female         Hoodie      Clothing
# 3896         3897   52  Female       Backpack   Accessories
# 3897         3898   46  Female           Belt   Accessories
# 3898         3899   44  Female          Shoes      Footwear
# 3899         3900   52  Female        Handbag   Accessories
#
#       Purchase_Amount_(USD)       Location      Color  Season  Review_Rating  \
# 0                        53       Kentucky       Gray  Winter            3.1
# 1                        64          Maine     Maroon  Winter            3.1
# ...

# %%
# sort original dataframe by volume of previous purchases and purchase amounts (highest first) to identify most loyal shoppers
df_sorted = df.sort_values(by=['Previous_Purchases', 'Purchase_Amount_(USD)'], ascending = False)
df_sorted
# Out:
#       Customer_ID  Age  Gender Item_Purchased Item_Category  \
# 455           456   54    Male         Blouse      Clothing
# 992           993   46    Male         Jacket     Outerwear
# 1737         1738   42    Male        Jewelry   Accessories
# 2229         2230   70    Male          Pants      Clothing
# 2484         2485   60    Male         Hoodie      Clothing
# ...           ...  ...     ...            ...           ...
# 104           105   55    Male     Sunglasses   Accessories
# 3332         3333   27  Female        T-shirt      Clothing
# 1663         1664   43    Male          Shirt      Clothing
# 2149         2150   38    Male        Sandals      Footwear
# 3142         3143   23  Female       Sneakers      Footwear
#
#       Purchase_Amount_(USD)       Location    Color  Season  Review_Rating  \
# 455                     100           Utah     Gold    Fall            3.6
# 992                      99      Louisiana     Gray  Winter            4.6
# ...

# %%
# create smaller sample of 500
np.random.seed(10)
df_500 = df_sorted.sample(n=500) # not grabbing top 500 it seems
df_500
# Out:
#       Customer_ID  Age  Gender Item_Purchased Item_Category  \
# 1249         1250   62    Male          Boots      Footwear
# 779           780   60    Male          Dress      Clothing
# 1546         1547   60    Male       Sneakers      Footwear
# 2766         2767   66  Female          Dress      Clothing
# 566           567   55    Male       Sneakers      Footwear
# ...           ...  ...     ...            ...           ...
# 3118         3119   61  Female         Shorts      Clothing
# 3115         3116   26  Female          Scarf   Accessories
# 133           134   52    Male        Sweater      Clothing
# 699           700   50    Male        Handbag   Accessories
# 2347         2348   37    Male           Belt   Accessories
#
#       Purchase_Amount_(USD)      Location     Color  Season  Review_Rating  \
# 1249                     50        Oregon     Peach  Winter            4.5
# 779                      94          Utah      Blue  Spring            4.6
# ...
